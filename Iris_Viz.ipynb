# %%
#importing the essentials

import pandas as pd 
import plotly.express as px 

from sklearn import datasets
import pandas as pd
import numpy as np
from bokeh.plotting import figure, show, output_notebook
import ipywidgets as widgets
from IPython.display import display, clear_output
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2485">Loading BokehJS ...</span>
#     </div>

# %%
# !conda install datapane -y
# !pip install bokeh
# !pip install sklearn
# Out:
# Collecting bokeh
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      |████████████████████████████████| 18.5 MB 5.4 MB/s eta 0:00:01     |██████████████████              | 10.5 MB 5.4 MB/s eta 0:00:02
# Requirement already satisfied: Jinja2>=2.9 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: numpy>=1.11.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from bokeh) (1.23.1)
# Requirement already satisfied: pillow>=7.1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from bokeh) (9.2.0)
# Requirement already satisfied: PyYAML>=3.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from bokeh) (6.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from bokeh) (4.3.0)
# Requirement already satisfied: tornado>=5.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from bokeh) (6.1)
# Requirement already satisfied: packaging>=16.8 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from bokeh) (21.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from packaging>=16.8->bokeh) (3.0.9)
# Installing collected packages: bokeh
# Successfully installed bokeh-2.4.3

# %%
#get the iris dataset
iris = datasets.load_iris()
data = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])

# %%
#For the dropdown - vizualization changes as the combination changes. 
#Might change it for future submissions (from TWO to 3D axes)
def var_dropdown(x):
    p = create_figure(
    x_dropdown.children[0].value,
    y_dropdown.children[0].value,
    data)
    fig[0] = p
     
    with output_figure:
        clear_output(True)
        show(fig[0])
    fig[0]=p
     
    return x
 
def create_figure(x_var, y_var, data):
    variety_colors=['coral', 'deepskyblue', 'darkblue']
    p = figure(title="",
               x_axis_label=x_var,
               y_axis_label=y_var)
    var_nr = 0
    
    for species in iris['target_names']:
        curr_dtps = data['target'] == var_nr
        circle = p.circle(
            data[x_var][curr_dtps],
            data[y_var][curr_dtps],
            line_width=2,
            color=variety_colors[var_nr],
            name=species
            )
        var_nr += 1
    return p
 
# The output widget is where we direct our figures
output_figure = widgets.Output()
 
# Create the default figure
fig = [] 
p = create_figure(
    iris['feature_names'][0],
    iris['feature_names'][1],
    data)
fig.append(p)
with output_figure:
    show(fig[0])

     
#Widgets
# for x-axis feature
x_dropdown = widgets.interactive(var_dropdown,
                                 x=iris['feature_names']);
x_dropdown.children[0].description = 'x-axis'
x_dropdown.children[0].value = iris['feature_names'][0]
 
# for y-axis feature
y_dropdown = widgets.interactive(var_dropdown,
                                 x=iris['feature_names']);
y_dropdown.children[0].description = 'y-axis'
y_dropdown.children[0].value = iris['feature_names'][1]
 
 
# This creates the menu 
menu=widgets.VBox([x_dropdown,
                   y_dropdown,
                   ])
 
"""Create the full app with menu and output"""
# The Layout adds some styling to our app.
# You can add Layout to any widget.
app_layout = widgets.Layout(display='flex',
                flex_flow='row nowrap',
                align_items='center',
                border='none',
                width='100%',
                margin='5px 5px 5px 5px')
 
# Box object
app=widgets.Box([menu, output_figure], layout=app_layout)
 
#output    
display(app)
# Out:
# Box(children=(VBox(children=(interactive(children=(Dropdown(description='x-axis', options=('sepal length (cm)'…
